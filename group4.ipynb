# %% [markdown]
# # ***Name - Shristi Koiry, Rachita Dey Sannyamat, Isha Tarafdar***
# # ***Group - 4***
# # ***Topic - Weather Forecasting Analysis & Visualization***

# %% [markdown]
# Mounting the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing the dataset

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/fINAL.csv")
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  01-01-2017  15.913043  85.869565    2.743478     59.000000
# 1  02-01-2017  18.500000  77.222222    2.894444   1018.277778
# 2  03-01-2017  17.111111  81.888889    4.016667   1018.333333
# 3  04-01-2017  18.700000  70.050000    4.545000   1015.700000
# 4  05-01-2017  18.388889  74.944444    3.300000   1014.333333

# %% [markdown]
# Total number of rows and columns

# %%
df.shape
# Out:
# (114, 5)

# %% [markdown]
# The index of the dataframe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=114, step=1)

# %% [markdown]
# Name of each column

# %%
df.columns
# Out:
# Index(['date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure'], dtype='object')

# %% [markdown]
# Data-type of each column

# %%
df.dtypes
# Out:
# date             object
# meantemp        float64
# humidity        float64
# wind_speed      float64
# meanpressure    float64
# dtype: object

# %% [markdown]
# Total number of unique values in each column

# %%
df.nunique()
# Out:
# date            114
# meantemp        105
# humidity        109
# wind_speed      107
# meanpressure    109
# dtype: int64

# %% [markdown]
# Total number of non-null values

# %%
df.count()
# Out:
# date            114
# meantemp        114
# humidity        114
# wind_speed      114
# meanpressure    114
# dtype: int64

# %% [markdown]
# Unique values with their count in the column

# %%
df.value_counts()
# Out:
# date        meantemp   humidity   wind_speed  meanpressure
# 01-01-2017  15.913043  85.869565  2.743478    59.000000       1
# 22-02-2017  19.125000  57.125000  7.412500    1012.250000     1
# 21-04-2017  34.250000  39.375000  6.962500    999.875000      1
# 21-03-2017  25.000000  49.000000  9.262500    1011.750000     1
# 21-02-2017  21.833333  69.416667  12.341667   1007.416667     1
#                                                              ..
# 09-03-2017  20.785714  69.071429  8.342857    1007.357143     1
# 09-02-2017  15.375000  68.375000  7.875000    1016.375000     1
# 09-01-2017  14.571429  80.809524  6.542857    1015.952381     1
# 08-04-2017  25.625000  29.375000  8.337500    1010.375000     1
# 31-03-2017  30.625000  37.625000  6.950000    1007.500000     1
# Length: 114, dtype: int64

# %% [markdown]
# Basic information about the dataframe

# %%
df.info
# Out:
# <bound method DataFrame.info of            date   meantemp   humidity  wind_speed  meanpressure
# 0    01-01-2017  15.913043  85.869565    2.743478     59.000000
# 1    02-01-2017  18.500000  77.222222    2.894444   1018.277778
# 2    03-01-2017  17.111111  81.888889    4.016667   1018.333333
# 3    04-01-2017  18.700000  70.050000    4.545000   1015.700000
# 4    05-01-2017  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  20-04-2017  34.500000  27.500000    5.562500    998.625000
# 110  21-04-2017  34.250000  39.375000    6.962500    999.875000
# 111  22-04-2017  32.900000  40.900000    8.890000   1001.600000
# 112  23-04-2017  32.875000  27.500000    9.962500   1002.125000
# 113  24-04-2017  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]>

# %% [markdown]
# To return the top n rows of a dataframe (by default value 5)

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  01-01-2017  15.913043  85.869565    2.743478     59.000000
# 1  02-01-2017  18.500000  77.222222    2.894444   1018.277778
# 2  03-01-2017  17.111111  81.888889    4.016667   1018.333333
# 3  04-01-2017  18.700000  70.050000    4.545000   1015.700000
# 4  05-01-2017  18.388889  74.944444    3.300000   1014.333333

# %% [markdown]
# Unique 'wind speed' values in the data.

# %%
df['wind_speed'].unique()
# Out:
# array([ 2.74347826,  2.89444444,  4.01666667,  4.545     ,  3.3       ,
#         8.68181818, 10.04166667,  1.95      ,  6.54285714,  9.36111111,
#         9.77222222,  6.62631579,  6.43529412,  5.276     ,  3.63043478,
#        10.38      ,  8.03888889,  6.02916667, 10.33809524, 11.22631579,
#        13.69565217,  5.868     ,  6.75294118,  3.39130435,  8.756     ,
#         8.46785714, 14.35833333,  9.69090909, 10.29444444,  4.32222222,
#         4.625     ,  5.1       ,  3.02727273,  1.85454546,  9.82      ,
#         8.1       ,  9.04444444,  7.6375    ,  4.08      ,  7.875     ,
#         9.06666667,  3.95      ,  1.625     ,  6.37777778,  6.9625    ,
#         5.55714286, 10.4375    ,  9.28      ,  6.25      ,  6.05454546,
#         6.9375    , 12.34166667,  7.4125    , 14.35      , 16.6625    ,
#        11.92857143, 11.1125    ,  3.91111111,  6.41538461,  5.93      ,
#         8.35      ,  9.9625    ,  9.66666667,  6.025     , 10.26363636,
# ...

# %% [markdown]
# 'meanpressure' count which is equal to 59

# %%
df[df['meanpressure']==59].count()
# Out:
# date            1
# meantemp        1
# humidity        1
# wind_speed      1
# meanpressure    1
# dtype: int64

# %% [markdown]
# Finding out the null values

# %%
df.isnull()
# Out:
#       date  meantemp  humidity  wind_speed  meanpressure
# 0    False     False     False       False         False
# 1    False     False     False       False         False
# 2    False     False     False       False         False
# 3    False     False     False       False         False
# 4    False     False     False       False         False
# ..     ...       ...       ...         ...           ...
# 109  False     False     False       False         False
# 110  False     False     False       False         False
# 111  False     False     False       False         False
# 112  False     False     False       False         False
# 113  False     False     False       False         False
#
# [114 rows x 5 columns]

# %% [markdown]
# Finding out the non null values

# %%
df.notnull()
# Out:
#      date  meantemp  humidity  wind_speed  meanpressure
# 0    True      True      True        True          True
# 1    True      True      True        True          True
# 2    True      True      True        True          True
# 3    True      True      True        True          True
# 4    True      True      True        True          True
# ..    ...       ...       ...         ...           ...
# 109  True      True      True        True          True
# 110  True      True      True        True          True
# 111  True      True      True        True          True
# 112  True      True      True        True          True
# 113  True      True      True        True          True
#
# [114 rows x 5 columns]

# %% [markdown]
# Renaming

# %%
df.rename(columns={'meantemp':'Temperature', 'meanpressure':'Pressure', 'wind_speed': 'Wind_speed', 'humidity': 'Humidity', 'date': 'Date'})
# Out:
#            Date  Temperature   Humidity  Wind_speed     Pressure
# 0    01-01-2017    15.913043  85.869565    2.743478    59.000000
# 1    02-01-2017    18.500000  77.222222    2.894444  1018.277778
# 2    03-01-2017    17.111111  81.888889    4.016667  1018.333333
# 3    04-01-2017    18.700000  70.050000    4.545000  1015.700000
# 4    05-01-2017    18.388889  74.944444    3.300000  1014.333333
# ..          ...          ...        ...         ...          ...
# 109  20-04-2017    34.500000  27.500000    5.562500   998.625000
# 110  21-04-2017    34.250000  39.375000    6.962500   999.875000
# 111  22-04-2017    32.900000  40.900000    8.890000  1001.600000
# 112  23-04-2017    32.875000  27.500000    9.962500  1002.125000
# 113  24-04-2017    32.000000  27.142857   12.157143  1004.142857
#
# [114 rows x 5 columns]

# %% [markdown]
# Renaming permanently

# %%
df.rename(columns={'meantemp':'Temperature', 'meanpressure':'Pressure', 'wind_speed': 'Wind_speed', 'humidity': 'Humidity', 'date': 'Date'}, inplace=True)

# %%
df
# Out:
#            Date  Temperature   Humidity  Wind_speed     Pressure
# 0    01-01-2017    15.913043  85.869565    2.743478    59.000000
# 1    02-01-2017    18.500000  77.222222    2.894444  1018.277778
# 2    03-01-2017    17.111111  81.888889    4.016667  1018.333333
# 3    04-01-2017    18.700000  70.050000    4.545000  1015.700000
# 4    05-01-2017    18.388889  74.944444    3.300000  1014.333333
# ..          ...          ...        ...         ...          ...
# 109  20-04-2017    34.500000  27.500000    5.562500   998.625000
# 110  21-04-2017    34.250000  39.375000    6.962500   999.875000
# 111  22-04-2017    32.900000  40.900000    8.890000  1001.600000
# 112  23-04-2017    32.875000  27.500000    9.962500  1002.125000
# 113  24-04-2017    32.000000  27.142857   12.157143  1004.142857
#
# [114 rows x 5 columns]

# %%
df
# Out:
#            Date  Temperature   Humidity  Wind_speed     Pressure
# 0    01-01-2017    15.913043  85.869565    2.743478    59.000000
# 1    02-01-2017    18.500000  77.222222    2.894444  1018.277778
# 2    03-01-2017    17.111111  81.888889    4.016667  1018.333333
# 3    04-01-2017    18.700000  70.050000    4.545000  1015.700000
# 4    05-01-2017    18.388889  74.944444    3.300000  1014.333333
# ..          ...          ...        ...         ...          ...
# 109  20-04-2017    34.500000  27.500000    5.562500   998.625000
# 110  21-04-2017    34.250000  39.375000    6.962500   999.875000
# 111  22-04-2017    32.900000  40.900000    8.890000  1001.600000
# 112  23-04-2017    32.875000  27.500000    9.962500  1002.125000
# 113  24-04-2017    32.000000  27.142857   12.157143  1004.142857
#
# [114 rows x 5 columns]

# %% [markdown]
# The Standard Deviation of 'Pressure'

# %%
df['Pressure'].std()
# Out:
# 89.47469205073058

# %% [markdown]
# Variance of 'Humidity'

# %%
df['Humidity'].var()
# Out:
# 363.5917836603916

# %% [markdown]
# Distributions, Time series and values

# %%
df
# Out:
#            Date  Temperature   Humidity  Wind_speed     Pressure
# 0    01-01-2017    15.913043  85.869565    2.743478    59.000000
# 1    02-01-2017    18.500000  77.222222    2.894444  1018.277778
# 2    03-01-2017    17.111111  81.888889    4.016667  1018.333333
# 3    04-01-2017    18.700000  70.050000    4.545000  1015.700000
# 4    05-01-2017    18.388889  74.944444    3.300000  1014.333333
# ..          ...          ...        ...         ...          ...
# 109  20-04-2017    34.500000  27.500000    5.562500   998.625000
# 110  21-04-2017    34.250000  39.375000    6.962500   999.875000
# 111  22-04-2017    32.900000  40.900000    8.890000  1001.600000
# 112  23-04-2017    32.875000  27.500000    9.962500  1002.125000
# 113  24-04-2017    32.000000  27.142857   12.157143  1004.142857
#
# [114 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df
# Out:
#            Date  Temperature   Humidity  Wind_speed     Pressure
# 0    01-01-2017    15.913043  85.869565    2.743478    59.000000
# 1    02-01-2017    18.500000  77.222222    2.894444  1018.277778
# 2    03-01-2017    17.111111  81.888889    4.016667  1018.333333
# 3    04-01-2017    18.700000  70.050000    4.545000  1015.700000
# 4    05-01-2017    18.388889  74.944444    3.300000  1014.333333
# ..          ...          ...        ...         ...          ...
# 109  20-04-2017    34.500000  27.500000    5.562500   998.625000
# 110  21-04-2017    34.250000  39.375000    6.962500   999.875000
# 111  22-04-2017    32.900000  40.900000    8.890000  1001.600000
# 112  23-04-2017    32.875000  27.500000    9.962500  1002.125000
# 113  24-04-2017    32.000000  27.142857   12.157143  1004.142857
#
# [114 rows x 5 columns]

# %%
df
# Out:
#            Date  Temperature   Humidity  Wind_speed     Pressure
# 0    01-01-2017    15.913043  85.869565    2.743478    59.000000
# 1    02-01-2017    18.500000  77.222222    2.894444  1018.277778
# 2    03-01-2017    17.111111  81.888889    4.016667  1018.333333
# 3    04-01-2017    18.700000  70.050000    4.545000  1015.700000
# 4    05-01-2017    18.388889  74.944444    3.300000  1014.333333
# ..          ...          ...        ...         ...          ...
# 109  20-04-2017    34.500000  27.500000    5.562500   998.625000
# 110  21-04-2017    34.250000  39.375000    6.962500   999.875000
# 111  22-04-2017    32.900000  40.900000    8.890000  1001.600000
# 112  23-04-2017    32.875000  27.500000    9.962500  1002.125000
# 113  24-04-2017    32.000000  27.142857   12.157143  1004.142857
#
# [114 rows x 5 columns]

# %% [markdown]
# Month check

# %%
pd.to_datetime(df['Date'])[32].strftime("%B")
# Out:
# <ipython-input-84-892a9f4836a0>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.to_datetime(df['Date'])[32].strftime("%B")
# 'February'

# %%
df.nunique()
# Out:
# Date           114
# Temperature    105
# Humidity       109
# Wind_speed     107
# Pressure       109
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x='Temperature', y='Humidity', data=df)
plt.show()

# %% [markdown]
# Calendar

# %%
import calendar
ml= list(calendar.month_name)
ml= ml[1:]
ml
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
df['Date']= pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0     2017-01-01
# 1     2017-02-01
# 2     2017-03-01
# 3     2017-04-01
# 4     2017-05-01
#          ...
# 109   2017-04-20
# 110   2017-04-21
# 111   2017-04-22
# 112   2017-04-23
# 113   2017-04-24
# Name: Date, Length: 114, dtype: datetime64[ns]

# %% [markdown]
# **Monthwise Temperature versus Humidity Graph**

# %% [markdown]
# January

# %%
df_Jan= df[df['Date']. dt. strftime('%Y-%m')=='2017-01']

# %%
df_Jan
# Out:
#          Date  Temperature   Humidity  Wind_speed     Pressure
# 0  2017-01-01    15.913043  85.869565    2.743478    59.000000
# 12 2017-01-13    13.235294  67.058824    6.435294  1017.529412
# 13 2017-01-14    13.200000  74.280000    5.276000  1018.840000
# 14 2017-01-15    16.434783  72.565217    3.630435  1018.130435
# 15 2017-01-16    14.650000  78.450000   10.380000  1017.150000
# 16 2017-01-17    11.722222  84.444444    8.038889  1018.388889
# 17 2017-01-18    13.041667  78.333333    6.029167  1021.958333
# 18 2017-01-19    14.619048  75.142857   10.338095  1022.809524
# 19 2017-01-20    15.263158  66.473684   11.226316  1021.789474
# 20 2017-01-21    15.391304  70.869565   13.695652  1020.478261
# 21 2017-01-22    18.440000  76.240000    5.868000  1021.040000
# 22 2017-01-23    18.117647  76.000000    6.752941  1019.823529
# 23 2017-01-24    18.347826  68.130435    3.391304  1018.869565
# 24 2017-01-25    21.000000  69.960000    8.756000  1018.400000
# ...

# %%
df_Jan.plot(kind='bar', y=df_Jan.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# February

# %%
df_Feb= df[df['Date']. dt. strftime('%Y-%m')=='2017-02']

# %%
df_Feb
# Out:
#          Date  Temperature   Humidity  Wind_speed     Pressure
# 1  2017-02-01    18.500000  77.222222    2.894444  1018.277778
# 32 2017-02-02    17.090909  66.545455    3.027273  1018.909091
# 43 2017-02-13    16.333333  67.000000    6.377778  1021.555556
# 44 2017-02-14    16.875000  65.500000    6.962500  1021.375000
# 45 2017-02-15    17.571429  67.714286    5.557143  1020.571429
# 46 2017-02-16    20.250000  56.750000   10.437500  1017.625000
# 47 2017-02-17    21.300000  64.400000    9.280000  1016.500000
# 48 2017-02-18    21.125000  70.750000    6.250000  1016.250000
# 49 2017-02-19    22.363636  66.090909    6.054545  1013.000000
# 50 2017-02-20    23.375000  60.125000    6.937500  1005.375000
# 51 2017-02-21    21.833333  69.416667   12.341667  1007.416667
# 52 2017-02-22    19.125000  57.125000    7.412500  1012.250000
# 53 2017-02-23    18.625000  42.875000   14.350000  1015.250000
# 54 2017-02-24    19.125000  40.375000   16.662500  1016.125000
# ...

# %%
df_Feb.plot(kind='bar', y=df_Feb.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# March

# %%
df_Mar= df[df['Date']. dt. strftime('%Y-%m')=='2017-03']

# %%
df_Mar.plot(kind='bar', y=df_Mar.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# April

# %%
df_Apr= df[df['Date']. dt. strftime('%Y-%m')=='2017-04']

# %%
df_Apr.plot(kind='bar', y=df_Apr.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# May

# %%
df_May= df[df['Date']. dt. strftime('%Y-%m')=='2017-05']

# %%
df_May.plot(kind='bar', y=df_May.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# June

# %%
df_Jun= df[df['Date']. dt. strftime('%Y-%m')=='2017-06']

# %%
df_Jun.plot(kind='bar', y=df_Jun.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# July

# %%
df_Jul= df[df['Date']. dt. strftime('%Y-%m')=='2017-07']

# %%
df_Jul.plot(kind='bar', y=df_Jul.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# August

# %%
df_Aug= df[df['Date']. dt. strftime('%Y-%m')=='2017-08']

# %%
df_Aug.plot(kind='bar', y=df_Aug.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# September

# %%
df_Sep= df[df['Date']. dt. strftime('%Y-%m')=='2017-09']

# %%
df_Sep.plot(kind='bar', y=df_Sep.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# October

# %%
df_Oct= df[df['Date']. dt. strftime('%Y-%m')=='2017-10']

# %%
df_Oct.plot(kind='bar', y=df_Oct.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# November

# %%
df_Nov= df[df['Date']. dt. strftime('%Y-%m')=='2017-11']

# %%
df_Nov.plot(kind='bar', y=df_Nov.columns[1:3])
# Out:
# <Axes: >

# %% [markdown]
# December

# %%
df_Dec= df[df['Date']. dt. strftime('%Y-%m')=='2017-12']

# %%
df_Dec.plot(kind='bar', y=df_Dec.columns[1:3])
# Out:
# <Axes: >
